# %%
import pandas as pd
import numpy as np

# %%
data_set = pd.read_csv('drugs_side_effects_drugs_com.csv')

# %%
data_set.isnull().sum()
# Out:
# drug_name                           0
# medical_condition                   0
# side_effects                      124
# generic_name                       43
# drug_classes                       82
# brand_names                      1213
# activity                            0
# rx_otc                              1
# pregnancy_category                229
# csa                                 0
# alcohol                          1554
# related_drugs                    1469
# medical_condition_description       0
# rating                           1345
# no_of_reviews                    1345
# drug_link                           0
# medical_condition_url               0
# dtype: int64

# %%
data_set__ =data_set.dropna()

# %%
data_set__.isnull().sum()
# Out:
# drug_name                        0
# medical_condition                0
# side_effects                     0
# generic_name                     0
# drug_classes                     0
# brand_names                      0
# activity                         0
# rx_otc                           0
# pregnancy_category               0
# csa                              0
# alcohol                          0
# related_drugs                    0
# medical_condition_description    0
# rating                           0
# no_of_reviews                    0
# drug_link                        0
# medical_condition_url            0
# dtype: int64

# %%
df=data_set__.drop(columns=['drug_link','medical_condition_url'])
df
# Out:
#                                               drug_name medical_condition  \
# 0                                           doxycycline              Acne
# 1                                        spironolactone              Acne
# 5                                             Aldactone              Acne
# 7                                          isotretinoin              Acne
# 22                                            Acticlate              Acne
# ...                                                 ...               ...
# 2886  hyoscyamine / methenamine / methylene blue / p...               UTI
# 2890                                         Phosphasal               UTI
# 2914                                    phendimetrazine       Weight Loss
# 2924                                            Lomaira       Weight Loss
# 2926                                      benzphetamine       Weight Loss
#
#                                            side_effects  \
# ...

# %%
# Save the modified DataFrame back to the CSV file
df.to_csv('drugs_side_effects_drugs_medical_condition.csv', index=False)

# %%
data = pd.read_csv('drugs_side_effects_drugs_medical_condition.csv')

# %%
data.shape
# Out:
# (251, 15)

# %%
data_.to_csv('newfile/drugs_side_effects_medical_condition.csv', index=False)

# %%
data__ = pd.read_csv('drugs_side_effects_medical_condition.csv')

# %%
data__
# Out:
#          drug_name medical_condition  \
# 0         trospium      Incontinence
# 1         Gelnique      Incontinence
# 2            Botox      Incontinence
# 3     fesoterodine      Incontinence
# 4      darifenacin      Incontinence
# ..             ...               ...
# 926  benzphetamine       Weight Loss
# 927   fenfluramine       Weight Loss
# 928    Fendique ER       Weight Loss
# 929       Imcivree       Weight Loss
# 930  setmelanotide       Weight Loss
#
#                                           side_effects  \
# 0    hives ; difficult breathing; swelling of your ...
# 1    hives ; difficult breathing; swelling of your ...
# 2    hives , itching; wheezing, difficult breathing...
# 3    hives ; difficult breathing; swelling of your ...
# 4    hives ; difficulty breathing; swelling of your...
# ..                                                 ...
# 926  hives ; difficulty breathing; swelling of your...
# 927  hives ; difficult breathing; swelling of your ...
# ...
